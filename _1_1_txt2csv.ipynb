# %%
import pandas as pd

# %%
read_file = pd.read_csv (r'D:\4_Summer23\DAP391m\top2\train\sentiments.txt')
read_file.to_csv (r'D:\4_Summer23\DAP391m\top2\train\sentiments.csv', index=None)

read_file = pd.read_csv (r'D:\4_Summer23\DAP391m\top2\train\sents.txt', sep='\t')
read_file.to_csv (r'D:\4_Summer23\DAP391m\top2\train\sents.csv', index=None)

# %%
df1 = pd.read_csv(r'D:\4_Summer23\DAP391m\top2\train\sents.csv', header = None)
df2 = pd.read_csv(r'D:\4_Summer23\DAP391m\top2\train\sentiments.csv', header = None)
file = pd.concat([df1, df2], axis=1, join='inner')
file.columns = ['text', 'label']
file.to_csv(r'D:\4_Summer23\DAP391m\top2\train.csv', index=None)
file
# Out:
#                                                     text  label
# 0                              slide giáo trình đầy đủ .      2
# 1         nhiệt tình giảng dạy , gần gũi với sinh viên .      2
# 2                   đi học đầy đủ full điểm chuyên cần .      0
# 3      chưa áp dụng công nghệ thông tin và các thiết ...      0
# 4      thầy giảng bài hay , có nhiều bài tập ví dụ ng...      2
# ...                                                  ...    ...
# 11421  chỉ vì môn game mà em học hai lần mà không qua...      0
# 11422                               em cảm ơn cô nhiều .      2
# 11423                           giao bài tập quá nhiều .      0
# 11424               giáo viên dạy dễ hiểu , nhiệt tình .      2
# 11425  gói gọn doubledot hay , tận tình , phù hợp với...      2
#
# [11426 rows x 2 columns]

# %% [markdown]
# Validation

# %%
read_file = pd.read_csv (r'D:\4_Summer23\DAP391m\top2\dev\sentiments.txt')
read_file.to_csv (r'D:\4_Summer23\DAP391m\top2\dev\sentiments.csv', index=None)
read_file = pd.read_csv (r'D:\4_Summer23\DAP391m\top2\dev\sents.txt', sep='\t')
read_file.to_csv (r'D:\4_Summer23\DAP391m\top2\dev\sents.csv', index=None)

# %%
df1 = pd.read_csv(r'D:\4_Summer23\DAP391m\top2\dev\sents.csv', header = None)
df2 = pd.read_csv(r'D:\4_Summer23\DAP391m\top2\dev\sentiments.csv', header = None)
file = pd.concat([df1, df2], axis=1, join='inner')
file.columns = ['Sentences', 'Sentiments']
file.to_csv(r'D:\4_Summer23\DAP391m\top2\val.csv', index=None)
file
# Out:
#                                               Sentences  Sentiments
# 0                              giáo trình chưa cụ thể .           0
# 1                                      giảng buồn ngủ .           0
# 2                        giáo viên vui tính , tận tâm .           2
# 3     giảng viên nên giao bài tập nhiều hơn , chia n...           0
# 4     giảng viên cần giảng bài chi tiết hơn , đi sâu...           0
# ...                                                 ...         ...
# 1578                              hướng dẫn lab mơ hồ .           0
# 1579  thầy cho chúng em những bài tập mang tính thực...           2
# 1580  thầy không dạy nhiều chủ yếu cho sinh viên tự ...           0
# 1581  em muốn đổi tên môn học vì tên môn là lập trìn...           0
# 1582  thầy vừa dạy vừa chat hoặc gọi điện thoại thườ...           0
#
# [1583 rows x 2 columns]

# %% [markdown]
# Test

# %%
read_file = pd.read_csv (r'D:\4_Summer23\DAP391m\top2\test\sentiments.txt')
read_file.to_csv (r'D:\4_Summer23\DAP391m\top2\test\sentiments.csv', index=None)
read_file = pd.read_csv (r'D:\4_Summer23\DAP391m\top2\test\sents.txt', sep='\t')
read_file.to_csv (r'D:\4_Summer23\DAP391m\top2\test\sents.csv', index=None)

# %%
df1 = pd.read_csv(r'D:\4_Summer23\DAP391m\top2\test\sents.csv', header = None)
df2 = pd.read_csv(r'D:\4_Summer23\DAP391m\top2\test\sentiments.csv', header = None)
file = pd.concat([df1, df2], axis=1, join='inner')
file.columns = ['text', 'label']
file.to_csv(r'D:\4_Summer23\DAP391m\top2\test.csv', index=None)
file
# Out:
#                                                    text  label
# 0                              nói tiếng anh lưu loát .      2
# 1                              giáo viên rất vui tính .      2
# 2                                       cô max có tâm .      2
# 3                          giảng bài thu hút , dí dỏm .      2
# 4     giáo viên không giảng dạy kiến thức , hướng dẫ...      0
# ...                                                 ...    ...
# 3161  các slide khó hiểu , ngôn ngữ trong slide phức...      0
# 3162                 giáo viên giảng dạy có tâm huyết .      2
# 3163                    chia sẻ cho em nhiều điều hay .      2
# 3164                                 em tiếp thu chậm .      0
# 3165  em có học ở một trung tâm tiếng anh ở ngoài tr...      1
#
# [3166 rows x 2 columns]
